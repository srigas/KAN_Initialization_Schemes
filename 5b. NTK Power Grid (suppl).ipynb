# %% [markdown]
# # NTK Results

# %% [markdown]
# ## Preliminaries

# %%
from jax import config
config.update("jax_enable_x64", True)

# %%
import pickle
import os

import jax
import jax.numpy as jnp

from src.utils import *
from src.functions import *
from src.pdes import *
from src.ntk import *

from flax import nnx
import optax

from jaxkan.KAN import KAN

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Function Fitting

# %% [markdown]
# We first perform experiments relevant to the NTK for the Function Fitting case, because PDEs have their own NTK formulation.

# %% [markdown]
# ### Parameters

# %%
N = 5000
n_ntk = 256

seed = 42

num_epochs = 2001
checkpoints = [0, 500, 1000, 1500, 2000]

opt_type = optax.adam(learning_rate=0.001)

pows = [0.0, 0.25, 0.5, 0.75, 1.0, 1.25, 1.5, 1.75, 2.0]

# Model input/output
n_in, n_out = 2, 1

# Studied functions
funcs = [("f3", f3)]

# %%
# --------------------------
# Small architecture details
# --------------------------
G_small = 5
hidden_small = [8, 8]

# ------------------------
# Big architecture details
# ------------------------
G_big = 20
hidden_big = [32, 32, 32]

# %% [markdown]
# ### Helper Functions

# %%
def get_data(func, N, n_ntk, seed):
    
    # Generate data
    x, y = generate_func_data(func, 2, N, seed)
    
    # Split data (at this point just to ensure continuity)
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=seed)
    
    # Subsample points used to compute NTK
    key_ntk = jax.random.PRNGKey(seed)
    idx = jax.random.choice(key_ntk, X_train.shape[0], shape=(n_ntk,), replace=False)
    X_ntk = X_train[idx]

    return X_train, y_train, X_ntk

# %%
def run_experiment(func, model, opt, X_train, y_train, X_ntk, title):
    spec_list, tau_list = [], []
    conds, ranks = [], []

    # τ = 0 (before any updates)
    K0 = stabilize_kernel(ntk_matrix(model, X_ntk))
    lam0 = jnp.sort(jnp.linalg.eigvalsh(K0))[::-1]
    spec_list.append(lam0)
    tau_list.append(0)
    conds.append(cond_from_eigs(lam0))
    
    eff_rank0 = (lam0.sum() ** 2) / (jnp.sum(lam0 ** 2) + 1e-12)
    ranks.append(float(eff_rank0))

    for epoch in range(num_epochs):
        loss = func_fit_step(model, opt, X_train, y_train)

        if epoch in checkpoints[1:]:
            Kt = stabilize_kernel(ntk_matrix(model, X_ntk))
            lam = jnp.sort(jnp.linalg.eigvalsh(Kt))[::-1]
            spec_list.append(lam)
            tau_list.append(epoch)
            conds.append(cond_from_eigs(lam))
            
            eff_rank_t = (lam.sum() ** 2) / (jnp.sum(lam ** 2) + 1e-12)
            ranks.append(float(eff_rank_t))

    l2error = func_fit_eval(model, func, 2, 200)

    print(f"\t{title} Model Metrics:")
    print(f"\tCond Number: τ=0 → {conds[0]:.2e}, τ={tau_list[-1]} → {conds[-1]:.2e}")
    print(f"\tEffective Rank: τ=0 → {ranks[0]:.2f}, τ={tau_list[-1]} → {ranks[-1]:.2f}")
    print(f"\tFinal Loss = {loss:.2e}\t L^2 Error = {l2error:.2e}\n")

    return spec_list, tau_list, conds, ranks

# %% [markdown]
# ### Main Routine

# %%
results = dict()

for func_name, func in funcs:
    
    results[func_name] = dict()

    for pow_basis in pows:
    
        results[func_name][pow_basis] = dict()

        for pow_res in pows:
    
            results[func_name][pow_basis][pow_res] = dict()

            params_small_power = {'k': 3, 'G': G_small, 'grid_range': (-1.0, 1.0), 'grid_e': 1.0, 'residual': nnx.silu, 'external_weights': True, 'add_bias': True,
                      'init_scheme': {'type': 'power', "const_b": 1.0, "const_r": 1.0, "pow_b1": pow_basis, "pow_b2": pow_basis, "pow_r1": pow_res, "pow_r2": pow_res}}

            params_big_power = {'k': 3, 'G': G_big, 'grid_range': (-1.0, 1.0), 'grid_e': 1.0, 'residual': nnx.silu, 'external_weights': True, 'add_bias': True,
                      'init_scheme': {'type': 'power', "const_b": 1.0, "const_r": 1.0, "pow_b1": pow_basis, "pow_b2": pow_basis, "pow_r1": pow_res, "pow_r2": pow_res}}

            # Get the data for the function
            X_train, y_train, X_ntk = get_data(func, N, n_ntk, seed)
        
            # Define the small architecture
            layer_dims = [n_in, *hidden_small, n_out]
        
            results[func_name][pow_basis][pow_res]["small"] = dict()
            
            print(f"Training model with dimensions {layer_dims} for function {func_name}.")
        
            # Power Law
            results[func_name][pow_basis][pow_res]["small"]["Power"] = dict()
            
            power_model = KAN(layer_dims = layer_dims, layer_type = 'spline', required_parameters = params_small_power, seed = seed+1)
            power_opt = nnx.Optimizer(power_model, opt_type)
        
            spec_list, tau_list, conds, ranks = run_experiment(func, power_model, power_opt, X_train, y_train, X_ntk, "Power")
            results[func_name][pow_basis][pow_res]["small"]["Power"]["spec_list"] = spec_list
            results[func_name][pow_basis][pow_res]["small"]["Power"]["tau_list"] = tau_list
            results[func_name][pow_basis][pow_res]["small"]["Power"]["conds"] = conds
            results[func_name][pow_basis][pow_res]["small"]["Power"]["ranks"] = ranks
        
        
            # Define the big architecture
            layer_dims = [n_in, *hidden_big, n_out]
        
            results[func_name][pow_basis][pow_res]["big"] = dict()
        
            print(f"Training model with dimensions {layer_dims} for function {func_name}.")
        
            # Power Law
            results[func_name][pow_basis][pow_res]["big"]["Power"] = dict()
            
            power_model = KAN(layer_dims = layer_dims, layer_type = 'spline', required_parameters = params_big_power, seed = seed+1)
            power_opt = nnx.Optimizer(power_model, opt_type)
        
            spec_list, tau_list, conds, ranks = run_experiment(func, power_model, power_opt, X_train, y_train, X_ntk, "Power")
            results[func_name][pow_basis][pow_res]["big"]["Power"]["spec_list"] = spec_list
            results[func_name][pow_basis][pow_res]["big"]["Power"]["tau_list"] = tau_list
            results[func_name][pow_basis][pow_res]["big"]["Power"]["conds"] = conds
            results[func_name][pow_basis][pow_res]["big"]["Power"]["ranks"] = ranks
# Out:
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 8.03e+06, τ=2000 → 3.17e+07
# 	Effective Rank: τ=0 → 17.93, τ=2000 → 18.33
# 	Final Loss = 5.35e-02	 L^2 Error = 2.47e-01
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 6.33e+03, τ=2000 → 7.79e+04
# 	Effective Rank: τ=0 → 47.46, τ=2000 → 40.89
# 	Final Loss = 1.60e+00	 L^2 Error = 1.42e+01
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.45e+07, τ=2000 → 2.52e+06
# 	Effective Rank: τ=0 → 19.47, τ=2000 → 20.70
# 	Final Loss = 6.39e-02	 L^2 Error = 2.88e-01
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.32e+04, τ=2000 → 1.83e+05
# 	Effective Rank: τ=0 → 69.00, τ=2000 → 74.51
# 	Final Loss = 3.64e-03	 L^2 Error = 6.11e-01
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.58e+07, τ=2000 → 1.94e+07
# 	Effective Rank: τ=0 → 21.26, τ=2000 → 21.86
# 	Final Loss = 3.81e-02	 L^2 Error = 2.27e-01
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 7.72e+02, τ=2000 → 1.29e+03
# 	Effective Rank: τ=0 → 75.69, τ=2000 → 74.57
# 	Final Loss = 1.20e-01	 L^2 Error = 6.00e-01
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 3.90e+07, τ=2000 → 1.22e+07
# 	Effective Rank: τ=0 → 20.79, τ=2000 → 22.82
# 	Final Loss = 4.10e-02	 L^2 Error = 2.32e-01
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 8.00e+02, τ=2000 → 1.39e+03
# 	Effective Rank: τ=0 → 72.63, τ=2000 → 68.99
# 	Final Loss = 3.25e-01	 L^2 Error = 6.12e-01
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 4.20e+07, τ=2000 → 6.76e+06
# 	Effective Rank: τ=0 → 20.41, τ=2000 → 21.96
# 	Final Loss = 3.06e-02	 L^2 Error = 2.04e-01
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 3.74e+02, τ=2000 → 1.86e+03
# 	Effective Rank: τ=0 → 76.73, τ=2000 → 61.79
# 	Final Loss = 8.88e-02	 L^2 Error = 6.09e-01
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 4.11e+07, τ=2000 → 4.34e+06
# 	Effective Rank: τ=0 → 20.27, τ=2000 → 23.38
# 	Final Loss = 2.95e-02	 L^2 Error = 2.00e-01
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 4.86e+02, τ=2000 → 1.44e+03
# 	Effective Rank: τ=0 → 73.01, τ=2000 → 69.85
# 	Final Loss = 1.57e-01	 L^2 Error = 6.06e-01
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 4.09e+07, τ=2000 → 2.25e+07
# 	Effective Rank: τ=0 → 20.14, τ=2000 → 23.56
# 	Final Loss = 3.51e-02	 L^2 Error = 2.25e-01
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 4.04e+02, τ=2000 → 4.90e+03
# 	Effective Rank: τ=0 → 73.24, τ=2000 → 76.00
# 	Final Loss = 1.19e-03	 L^2 Error = 6.22e-01
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 4.15e+07, τ=2000 → 3.24e+06
# 	Effective Rank: τ=0 → 20.08, τ=2000 → 23.16
# 	Final Loss = 3.19e-02	 L^2 Error = 2.18e-01
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 5.07e+02, τ=2000 → 1.17e+03
# 	Effective Rank: τ=0 → 77.09, τ=2000 → 66.90
# 	Final Loss = 4.09e-01	 L^2 Error = 6.13e-01
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 4.20e+07, τ=2000 → 6.93e+06
# 	Effective Rank: τ=0 → 20.05, τ=2000 → 22.98
# 	Final Loss = 3.45e-02	 L^2 Error = 2.27e-01
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 5.33e+02, τ=2000 → 1.09e+03
# 	Effective Rank: τ=0 → 73.26, τ=2000 → 74.24
# 	Final Loss = 8.38e-02	 L^2 Error = 6.04e-01
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 5.25e+07, τ=2000 → 3.34e+08
# 	Effective Rank: τ=0 → 15.29, τ=2000 → 11.26
# 	Final Loss = 1.71e-03	 L^2 Error = 4.10e-02
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 5.67e+02, τ=2000 → 6.96e+02
# 	Effective Rank: τ=0 → 82.74, τ=2000 → 76.67
# 	Final Loss = 3.12e-05	 L^2 Error = 5.13e+00
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 2.03e+08, τ=2000 → 4.32e+08
# 	Effective Rank: τ=0 → 18.37, τ=2000 → 12.94
# 	Final Loss = 7.52e-04	 L^2 Error = 2.78e-02
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 7.03e+01, τ=2000 → 8.39e+01
# 	Effective Rank: τ=0 → 88.18, τ=2000 → 88.31
# 	Final Loss = 9.51e-13	 L^2 Error = 6.44e-01
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 2.26e+08, τ=2000 → 3.77e+08
# 	Effective Rank: τ=0 → 19.77, τ=2000 → 14.06
# 	Final Loss = 7.36e-04	 L^2 Error = 2.73e-02
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 7.56e+01, τ=2000 → 5.94e+01
# 	Effective Rank: τ=0 → 88.22, τ=2000 → 91.92
# 	Final Loss = 1.79e-14	 L^2 Error = 7.15e-01
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 2.51e+08, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 19.15, τ=2000 → 10.27
# 	Final Loss = 4.68e-04	 L^2 Error = 2.15e-02
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 7.90e+01, τ=2000 → 6.98e+01
# 	Effective Rank: τ=0 → 88.27, τ=2000 → 89.08
# 	Final Loss = 3.33e-08	 L^2 Error = 5.88e-01
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 2.46e+08, τ=2000 → 3.45e+08
# 	Effective Rank: τ=0 → 18.78, τ=2000 → 11.87
# 	Final Loss = 5.12e-04	 L^2 Error = 2.32e-02
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 7.40e+01, τ=2000 → 7.37e+01
# 	Effective Rank: τ=0 → 88.41, τ=2000 → 88.95
# 	Final Loss = 1.68e-14	 L^2 Error = 5.97e-01
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 2.48e+08, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 18.49, τ=2000 → 10.14
# 	Final Loss = 4.25e-04	 L^2 Error = 2.08e-02
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 7.24e+01, τ=2000 → 6.46e+01
# 	Effective Rank: τ=0 → 88.62, τ=2000 → 91.26
# 	Final Loss = 2.95e-06	 L^2 Error = 6.33e-01
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 2.46e+08, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 18.35, τ=2000 → 10.09
# 	Final Loss = 4.17e-04	 L^2 Error = 2.08e-02
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 5.86e+01, τ=2000 → 7.97e+01
# 	Effective Rank: τ=0 → 89.94, τ=2000 → 87.71
# 	Final Loss = 4.07e-12	 L^2 Error = 6.06e-01
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 2.45e+08, τ=2000 → 7.82e+08
# 	Effective Rank: τ=0 → 18.29, τ=2000 → 9.73
# 	Final Loss = 4.30e-04	 L^2 Error = 2.09e-02
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 6.25e+01, τ=2000 → 8.25e+01
# 	Effective Rank: τ=0 → 88.30, τ=2000 → 89.93
# 	Final Loss = 8.68e-15	 L^2 Error = 5.96e-01
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 2.45e+08, τ=2000 → 5.45e+08
# 	Effective Rank: τ=0 → 18.26, τ=2000 → 9.38
# 	Final Loss = 4.14e-04	 L^2 Error = 2.08e-02
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 7.41e+01, τ=2000 → 6.07e+01
# 	Effective Rank: τ=0 → 88.29, τ=2000 → 89.71
# 	Final Loss = 6.54e-14	 L^2 Error = 5.98e-01
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 4.83, τ=2000 → 5.32
# 	Final Loss = 9.60e-05	 L^2 Error = 1.02e-02
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 3.12e+05, τ=2000 → 1.57e+04
# 	Effective Rank: τ=0 → 14.25, τ=2000 → 18.11
# 	Final Loss = 1.24e-04	 L^2 Error = 3.56e-01
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 2.31, τ=2000 → 4.52
# 	Final Loss = 3.77e-05	 L^2 Error = 6.14e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 2.38e+04, τ=2000 → 2.24e+04
# 	Effective Rank: τ=0 → 116.59, τ=2000 → 125.65
# 	Final Loss = 4.11e-08	 L^2 Error = 6.86e-02
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.72, τ=2000 → 2.70
# 	Final Loss = 4.93e-05	 L^2 Error = 6.67e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 2.66e+04, τ=2000 → 2.79e+04
# 	Effective Rank: τ=0 → 88.37, τ=2000 → 104.85
# 	Final Loss = 1.91e-07	 L^2 Error = 8.45e-02
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.67, τ=2000 → 2.87
# 	Final Loss = 3.22e-05	 L^2 Error = 5.48e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 4.14e+04, τ=2000 → 2.76e+04
# 	Effective Rank: τ=0 → 85.01, τ=2000 → 102.79
# 	Final Loss = 4.47e-07	 L^2 Error = 8.58e-02
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.65, τ=2000 → 2.80
# 	Final Loss = 2.53e-05	 L^2 Error = 5.09e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 4.24e+04, τ=2000 → 2.38e+04
# 	Effective Rank: τ=0 → 84.22, τ=2000 → 105.23
# 	Final Loss = 4.25e-07	 L^2 Error = 9.44e-02
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.64, τ=2000 → 2.86
# 	Final Loss = 2.75e-05	 L^2 Error = 5.18e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 4.20e+04, τ=2000 → 4.21e+04
# 	Effective Rank: τ=0 → 83.91, τ=2000 → 100.02
# 	Final Loss = 3.35e-06	 L^2 Error = 9.45e-02
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.63, τ=2000 → 2.89
# 	Final Loss = 2.82e-05	 L^2 Error = 5.20e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 4.12e+04, τ=2000 → 1.47e+04
# 	Effective Rank: τ=0 → 84.03, τ=2000 → 96.25
# 	Final Loss = 3.81e-07	 L^2 Error = 9.59e-02
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.63, τ=2000 → 2.89
# 	Final Loss = 2.85e-05	 L^2 Error = 5.22e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 4.18e+04, τ=2000 → 3.10e+04
# 	Effective Rank: τ=0 → 84.09, τ=2000 → 95.00
# 	Final Loss = 2.25e-07	 L^2 Error = 9.34e-02
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.62, τ=2000 → 2.89
# 	Final Loss = 2.87e-05	 L^2 Error = 5.23e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 4.22e+04, τ=2000 → 2.12e+04
# 	Effective Rank: τ=0 → 84.11, τ=2000 → 97.75
# 	Final Loss = 1.96e-07	 L^2 Error = 9.25e-02
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 2.83, τ=2000 → 3.32
# 	Final Loss = 1.89e-05	 L^2 Error = 4.11e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 8.54e+06, τ=2000 → 2.31e+06
# 	Effective Rank: τ=0 → 7.62, τ=2000 → 6.72
# 	Final Loss = 1.44e-04	 L^2 Error = 4.93e-02
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.28, τ=2000 → 3.01
# 	Final Loss = 6.18e-06	 L^2 Error = 2.34e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 6.76e+08, τ=2000 → 7.56e+07
# 	Effective Rank: τ=0 → 2.29, τ=2000 → 7.77
# 	Final Loss = 3.21e-07	 L^2 Error = 7.92e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.05, τ=2000 → 2.25
# 	Final Loss = 5.59e-06	 L^2 Error = 2.30e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 3.21e+08
# 	Effective Rank: τ=0 → 1.03, τ=2000 → 5.68
# 	Final Loss = 4.80e-07	 L^2 Error = 1.46e-03
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.02, τ=2000 → 2.30
# 	Final Loss = 4.83e-06	 L^2 Error = 2.12e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 5.76e+08
# 	Effective Rank: τ=0 → 1.02, τ=2000 → 5.61
# 	Final Loss = 6.60e-07	 L^2 Error = 1.58e-03
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.01, τ=2000 → 2.23
# 	Final Loss = 5.20e-06	 L^2 Error = 2.18e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 5.76e+08
# 	Effective Rank: τ=0 → 1.01, τ=2000 → 5.96
# 	Final Loss = 5.58e-07	 L^2 Error = 1.90e-03
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.01, τ=2000 → 2.26
# 	Final Loss = 4.80e-06	 L^2 Error = 2.09e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 7.06e+08
# 	Effective Rank: τ=0 → 1.01, τ=2000 → 5.59
# 	Final Loss = 6.21e-07	 L^2 Error = 1.73e-03
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.01, τ=2000 → 2.27
# 	Final Loss = 4.73e-06	 L^2 Error = 2.07e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 6.84e+08
# 	Effective Rank: τ=0 → 1.01, τ=2000 → 6.05
# 	Final Loss = 4.40e-07	 L^2 Error = 1.58e-03
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.01, τ=2000 → 2.28
# 	Final Loss = 4.72e-06	 L^2 Error = 2.07e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 5.94e+08
# 	Effective Rank: τ=0 → 1.01, τ=2000 → 6.04
# 	Final Loss = 5.25e-07	 L^2 Error = 1.84e-03
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.01, τ=2000 → 2.28
# 	Final Loss = 4.74e-06	 L^2 Error = 2.07e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 5.73e+08
# 	Effective Rank: τ=0 → 1.01, τ=2000 → 6.17
# 	Final Loss = 4.39e-05	 L^2 Error = 4.45e-03
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 2.47, τ=2000 → 3.57
# 	Final Loss = 7.45e-06	 L^2 Error = 2.57e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 6.45e+07, τ=2000 → 1.79e+07
# 	Effective Rank: τ=0 → 7.07, τ=2000 → 6.28
# 	Final Loss = 5.63e-05	 L^2 Error = 2.14e-02
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.17, τ=2000 → 2.48
# 	Final Loss = 6.65e-06	 L^2 Error = 2.47e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.83, τ=2000 → 6.31
# 	Final Loss = 9.22e-08	 L^2 Error = 3.24e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.01, τ=2000 → 2.45
# 	Final Loss = 3.32e-06	 L^2 Error = 1.71e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 5.25
# 	Final Loss = 5.24e-04	 L^2 Error = 1.91e-02
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.52
# 	Final Loss = 2.12e-06	 L^2 Error = 1.41e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 5.23
# 	Final Loss = 3.28e-07	 L^2 Error = 6.50e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.47
# 	Final Loss = 2.17e-06	 L^2 Error = 1.39e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 5.59
# 	Final Loss = 2.25e-06	 L^2 Error = 1.27e-03
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.48
# 	Final Loss = 2.69e-06	 L^2 Error = 1.53e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 5.53
# 	Final Loss = 1.23e-06	 L^2 Error = 1.25e-03
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.48
# 	Final Loss = 2.70e-06	 L^2 Error = 1.53e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 5.60
# 	Final Loss = 9.66e-06	 L^2 Error = 1.83e-03
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.48
# 	Final Loss = 2.76e-06	 L^2 Error = 1.54e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 5.40
# 	Final Loss = 3.38e-07	 L^2 Error = 7.05e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.48
# 	Final Loss = 2.80e-06	 L^2 Error = 1.55e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 5.45
# 	Final Loss = 3.81e-07	 L^2 Error = 7.80e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 2.36, τ=2000 → 3.41
# 	Final Loss = 5.57e-06	 L^2 Error = 2.21e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 3.78e+08, τ=2000 → 1.91e+08
# 	Effective Rank: τ=0 → 6.96, τ=2000 → 6.23
# 	Final Loss = 2.41e-05	 L^2 Error = 1.51e-02
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.13, τ=2000 → 2.32
# 	Final Loss = 4.28e-06	 L^2 Error = 1.99e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.80, τ=2000 → 6.39
# 	Final Loss = 3.47e-08	 L^2 Error = 2.12e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.01, τ=2000 → 2.42
# 	Final Loss = 5.07e-06	 L^2 Error = 2.15e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 4.64
# 	Final Loss = 1.49e-07	 L^2 Error = 4.22e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.44
# 	Final Loss = 3.28e-06	 L^2 Error = 1.67e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 4.57
# 	Final Loss = 1.62e-07	 L^2 Error = 3.98e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.48
# 	Final Loss = 2.92e-06	 L^2 Error = 1.59e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 4.91
# 	Final Loss = 7.18e-07	 L^2 Error = 8.61e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.52
# 	Final Loss = 3.08e-06	 L^2 Error = 1.66e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 5.62
# 	Final Loss = 1.87e-07	 L^2 Error = 1.03e-03
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.54
# 	Final Loss = 3.35e-06	 L^2 Error = 1.74e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 5.51
# 	Final Loss = 4.00e-05	 L^2 Error = 3.53e-03
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.54
# 	Final Loss = 3.45e-06	 L^2 Error = 1.77e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 5.22
# 	Final Loss = 1.71e-07	 L^2 Error = 7.30e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.54
# 	Final Loss = 3.48e-06	 L^2 Error = 1.78e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 5.33
# 	Final Loss = 7.81e-07	 L^2 Error = 1.08e-03
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 2.31, τ=2000 → 3.21
# 	Final Loss = 2.92e-06	 L^2 Error = 1.56e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 6.20e+08, τ=2000 → 2.97e+08
# 	Effective Rank: τ=0 → 6.93, τ=2000 → 6.24
# 	Final Loss = 1.61e-05	 L^2 Error = 1.35e-02
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.12, τ=2000 → 2.36
# 	Final Loss = 4.23e-06	 L^2 Error = 1.98e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.80, τ=2000 → 6.35
# 	Final Loss = 1.74e-08	 L^2 Error = 1.44e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.01, τ=2000 → 2.44
# 	Final Loss = 5.88e-06	 L^2 Error = 2.31e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 4.45
# 	Final Loss = 1.55e-07	 L^2 Error = 4.03e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.44
# 	Final Loss = 3.66e-06	 L^2 Error = 1.80e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 4.90
# 	Final Loss = 1.03e-07	 L^2 Error = 3.21e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.55
# 	Final Loss = 4.63e-06	 L^2 Error = 2.03e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 5.20
# 	Final Loss = 2.87e-07	 L^2 Error = 8.60e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.54
# 	Final Loss = 4.18e-06	 L^2 Error = 1.90e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 4.81
# 	Final Loss = 2.26e-07	 L^2 Error = 5.95e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.53
# 	Final Loss = 3.67e-06	 L^2 Error = 1.81e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 4.67
# 	Final Loss = 2.42e-07	 L^2 Error = 7.50e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.55
# 	Final Loss = 3.80e-06	 L^2 Error = 1.85e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 5.89
# 	Final Loss = 2.98e-07	 L^2 Error = 8.02e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.56
# 	Final Loss = 3.83e-06	 L^2 Error = 1.85e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 5.32
# 	Final Loss = 7.73e-07	 L^2 Error = 1.14e-03
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 2.29, τ=2000 → 3.19
# 	Final Loss = 3.51e-06	 L^2 Error = 1.73e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 7.87e+08, τ=2000 → 3.69e+08
# 	Effective Rank: τ=0 → 6.92, τ=2000 → 6.24
# 	Final Loss = 1.49e-05	 L^2 Error = 1.36e-02
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.12, τ=2000 → 2.37
# 	Final Loss = 4.35e-06	 L^2 Error = 1.99e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.80, τ=2000 → 6.58
# 	Final Loss = 2.70e-05	 L^2 Error = 3.56e-03
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.43
# 	Final Loss = 5.99e-06	 L^2 Error = 2.32e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 4.43
# 	Final Loss = 5.19e-08	 L^2 Error = 2.31e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.44
# 	Final Loss = 4.21e-06	 L^2 Error = 1.92e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 5.57
# 	Final Loss = 2.96e-07	 L^2 Error = 5.71e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.50
# 	Final Loss = 3.83e-06	 L^2 Error = 1.87e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 5.77
# 	Final Loss = 4.25e-07	 L^2 Error = 7.84e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.60
# 	Final Loss = 4.14e-06	 L^2 Error = 1.89e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 5.01
# 	Final Loss = 2.90e-07	 L^2 Error = 8.49e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.50
# 	Final Loss = 3.90e-06	 L^2 Error = 1.83e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 5.00
# 	Final Loss = 3.74e-07	 L^2 Error = 7.88e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.55
# 	Final Loss = 4.13e-06	 L^2 Error = 1.88e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 5.01
# 	Final Loss = 5.52e-07	 L^2 Error = 1.37e-03
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.52
# 	Final Loss = 4.20e-06	 L^2 Error = 1.92e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 4.85
# 	Final Loss = 1.28e-06	 L^2 Error = 1.27e-03
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 2.29, τ=2000 → 3.17
# 	Final Loss = 3.63e-06	 L^2 Error = 1.77e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 7.71e+08, τ=2000 → 3.91e+08
# 	Effective Rank: τ=0 → 6.91, τ=2000 → 6.23
# 	Final Loss = 1.47e-05	 L^2 Error = 1.38e-02
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.12, τ=2000 → 2.38
# 	Final Loss = 4.15e-06	 L^2 Error = 1.89e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.80, τ=2000 → 6.52
# 	Final Loss = 1.65e-08	 L^2 Error = 1.46e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.43
# 	Final Loss = 5.89e-06	 L^2 Error = 2.30e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 4.37
# 	Final Loss = 5.24e-08	 L^2 Error = 2.43e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.45
# 	Final Loss = 4.61e-06	 L^2 Error = 2.00e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 5.28
# 	Final Loss = 9.06e-08	 L^2 Error = 3.46e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.51
# 	Final Loss = 4.48e-06	 L^2 Error = 1.99e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 5.87
# 	Final Loss = 1.23e-06	 L^2 Error = 1.25e-03
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.52
# 	Final Loss = 3.99e-06	 L^2 Error = 1.86e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 4.41
# 	Final Loss = 2.88e-06	 L^2 Error = 2.17e-03
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.56
# 	Final Loss = 4.65e-06	 L^2 Error = 1.98e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 4.89
# 	Final Loss = 1.77e-07	 L^2 Error = 6.12e-04
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.49
# 	Final Loss = 4.71e-06	 L^2 Error = 2.03e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 4.84
# 	Final Loss = 2.22e-06	 L^2 Error = 1.92e-03
#
# Training model with dimensions [2, 8, 8, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 2.51
# 	Final Loss = 4.70e-06	 L^2 Error = 2.03e-03
#
# Training model with dimensions [2, 32, 32, 32, 1] for function f3.
# 	Power Model Metrics:
# 	Cond Number: τ=0 → 1.00e+09, τ=2000 → 1.00e+09
# 	Effective Rank: τ=0 → 1.00, τ=2000 → 5.09
# 	Final Loss = 6.74e-06	 L^2 Error = 2.03e-03

# %%
# Save results for further processing
results_dir = 'ff_results/'

with open(os.path.join(results_dir, "ntk_powgrid.pkl"), "wb") as f:
    pickle.dump(results, f)
