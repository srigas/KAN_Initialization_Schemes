# %% [markdown]
# # Training Loss Curves

# %%
import pickle
import os

import jax.numpy as jnp

from src.functions import *
from src.pdes import *
from src.utils import *

from jaxkan.KAN import KAN

from flax import nnx
import optax

from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Function Fitting

# %% [markdown]
# We proceed with the training of the two networks mentioned in the manuscript to show the evolution of the training loss for each function, under the selected initialization techniques.

# %%
# Setup
func_dict = {"f1": f1, "f2": f2, "f3": f3, "f4": f4, "f5": f5}

N = 5000
seed = 42

num_epochs = 2000

opt_type = optax.adam(learning_rate=0.001)

pow_basis = 1.75
pow_res = 0.25

# --------------------------
# Small architecture details
# --------------------------
G_small = 5
hidden_small = [8, 8]

params_small_lecun = {'k': 3, 'G': G_small, 'grid_range': (-1.0, 1.0), 'grid_e': 1.0, 'residual': nnx.silu, 'external_weights': True, 'add_bias': True,
                         'init_scheme': {'type': 'lecun', 'gain': None, 'distribution': 'uniform'}}

# ------------------------
# Big architecture details
# ------------------------
G_big = 20
hidden_big = [32, 32, 32]

params_big_lecun = {'k': 3, 'G': G_big, 'grid_range': (-1.0, 1.0), 'grid_e': 1.0, 'residual': nnx.silu, 'external_weights': True, 'add_bias': True,
                         'init_scheme': {'type': 'lecun', 'gain': None, 'distribution': 'uniform'}}

# %%
# Initialize results dict
results = dict()

for func_name in func_dict.keys():
    print(f"Running Experiments for {func_name}.")
    function = func_dict[func_name]
    results[func_name] = dict()

    results[func_name]['small'] = dict()
    results[func_name]['big'] = dict()

    # Generate data
    x, y = generate_func_data(function, 2, N, seed)

    # Split data (in this case we do not care about mse loss, but we're doing it for consistency)
    X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=seed)

    # Model input/output
    n_in, n_out = X_train.shape[1], y_train.shape[1]

    # Small architecture
    layer_dims = [n_in, *hidden_small, n_out]

    print(f"\tTraining model with dimensions {layer_dims}.")

    # For confidence
    for run in [1, 2, 3, 4, 5]:

        results[func_name]['small'][run] = dict()

        print(f"\t\tRun No. {run}.")

        # LeCun
        base_model = KAN(layer_dims = layer_dims, layer_type = 'spline', required_parameters = params_small_lecun, seed = seed+run)
        base_opt = nnx.Optimizer(base_model, opt_type)

        train_losses = jnp.zeros((num_epochs,))
        for epoch in range(num_epochs):
            loss = func_fit_step(base_model, base_opt, X_train, y_train)
            train_losses = train_losses.at[epoch].set(loss)

        results[func_name]['small'][run]['lecun'] = train_losses.copy()

        print(f"\t\t\tLeCun model: Final Loss = {loss:.2e}")

    # Big architecture
    layer_dims = [n_in, *hidden_big, n_out]

    print(f"\tTraining model with dimensions {layer_dims}.")

    # For confidence
    for run in [1, 2, 3, 4, 5]:

        results[func_name]['big'][run] = dict()

        print(f"\t\tRun No. {run}.")

        # Baseline
        base_model = KAN(layer_dims = layer_dims, layer_type = 'spline', required_parameters = params_big_lecun, seed = seed+run)
        base_opt = nnx.Optimizer(base_model, opt_type)

        train_losses = jnp.zeros((num_epochs,))
        for epoch in range(num_epochs):
            loss = func_fit_step(base_model, base_opt, X_train, y_train)
            train_losses = train_losses.at[epoch].set(loss)

        results[func_name]['big'][run]['lecun'] = train_losses.copy()

        print(f"\t\t\tLeCun model: Final Loss = {loss:.2e}")
# Out:
# Running Experiments for f1.
# 	Training model with dimensions [2, 8, 8, 1].
# 		Run No. 1.
# 2025-11-14 10:24:26.577350: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 			LeCun model: Final Loss = 2.00e-04
# 		Run No. 2.
# 			LeCun model: Final Loss = 1.12e-04
# 		Run No. 3.
# 			LeCun model: Final Loss = 2.07e-04
# 		Run No. 4.
# 			LeCun model: Final Loss = 2.57e-04
# 		Run No. 5.
# 			LeCun model: Final Loss = 2.28e-04
# 	Training model with dimensions [2, 32, 32, 32, 1].
# 		Run No. 1.
# 2025-11-14 10:24:47.825823: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 			LeCun model: Final Loss = 2.19e-04
# 		Run No. 2.
# 			LeCun model: Final Loss = 3.03e-04
# 		Run No. 3.
# 			LeCun model: Final Loss = 2.01e-04
# 		Run No. 4.
# 			LeCun model: Final Loss = 2.75e-04
# 		Run No. 5.
# 			LeCun model: Final Loss = 2.27e-04
# Running Experiments for f2.
# 	Training model with dimensions [2, 8, 8, 1].
# 		Run No. 1.
# 			LeCun model: Final Loss = 2.46e-03
# 		Run No. 2.
# 			LeCun model: Final Loss = 2.22e-03
# 		Run No. 3.
# 			LeCun model: Final Loss = 3.78e-03
# 		Run No. 4.
# 			LeCun model: Final Loss = 1.86e-03
# 		Run No. 5.
# 			LeCun model: Final Loss = 3.77e-03
# 	Training model with dimensions [2, 32, 32, 32, 1].
# 		Run No. 1.
# 			LeCun model: Final Loss = 2.75e-03
# 		Run No. 2.
# 			LeCun model: Final Loss = 2.70e-03
# 		Run No. 3.
# 			LeCun model: Final Loss = 2.97e-03
# 		Run No. 4.
# 			LeCun model: Final Loss = 3.12e-03
# 		Run No. 5.
# 			LeCun model: Final Loss = 2.57e-03
# Running Experiments for f3.
# 	Training model with dimensions [2, 8, 8, 1].
# 		Run No. 1.
# 			LeCun model: Final Loss = 5.03e-04
# 		Run No. 2.
# 			LeCun model: Final Loss = 4.26e-04
# 		Run No. 3.
# 			LeCun model: Final Loss = 9.19e-04
# 		Run No. 4.
# 			LeCun model: Final Loss = 2.49e-04
# 		Run No. 5.
# 			LeCun model: Final Loss = 8.83e-04
# 	Training model with dimensions [2, 32, 32, 32, 1].
# 		Run No. 1.
# 			LeCun model: Final Loss = 7.70e-04
# 		Run No. 2.
# 			LeCun model: Final Loss = 8.38e-04
# 		Run No. 3.
# 			LeCun model: Final Loss = 8.33e-04
# 		Run No. 4.
# 			LeCun model: Final Loss = 5.00e-04
# 		Run No. 5.
# 			LeCun model: Final Loss = 9.71e-04
# Running Experiments for f4.
# 	Training model with dimensions [2, 8, 8, 1].
# 		Run No. 1.
# 			LeCun model: Final Loss = 4.57e-04
# 		Run No. 2.
# 			LeCun model: Final Loss = 3.84e-04
# 		Run No. 3.
# 			LeCun model: Final Loss = 7.25e-04
# 		Run No. 4.
# 			LeCun model: Final Loss = 4.00e-04
# 		Run No. 5.
# 			LeCun model: Final Loss = 7.02e-04
# 	Training model with dimensions [2, 32, 32, 32, 1].
# 		Run No. 1.
# 			LeCun model: Final Loss = 1.94e-04
# 		Run No. 2.
# 			LeCun model: Final Loss = 2.65e-04
# 		Run No. 3.
# 			LeCun model: Final Loss = 1.61e-04
# 		Run No. 4.
# 			LeCun model: Final Loss = 2.61e-04
# 		Run No. 5.
# 			LeCun model: Final Loss = 1.64e-04
# Running Experiments for f5.
# 	Training model with dimensions [2, 8, 8, 1].
# 		Run No. 1.
# 			LeCun model: Final Loss = 2.94e-03
# 		Run No. 2.
# 			LeCun model: Final Loss = 1.91e-03
# 		Run No. 3.
# 			LeCun model: Final Loss = 3.02e-03
# 		Run No. 4.
# 			LeCun model: Final Loss = 2.86e-03
# 		Run No. 5.
# 			LeCun model: Final Loss = 2.73e-03
# 	Training model with dimensions [2, 32, 32, 32, 1].
# 		Run No. 1.
# 			LeCun model: Final Loss = 7.13e-04
# 		Run No. 2.
# 			LeCun model: Final Loss = 2.86e-01
# 		Run No. 3.
# 			LeCun model: Final Loss = 4.77e-04
# 		Run No. 4.
# 			LeCun model: Final Loss = 6.16e-04
# 		Run No. 5.
# 			LeCun model: Final Loss = 3.89e-04

# %%
# Save results for further processing
results_dir = 'ff_results/'

with open(os.path.join(results_dir, "losses_lecun.pkl"), "wb") as f:
    pickle.dump(results, f)

# %% [markdown]
# ## PDE

# %% [markdown]
# And likewise for the PDEs.

# %%
# Setup
pde_dict = {"allen-cahn": ac_res, "burgers": burgers_res, "helmholtz": helmholtz_res}

N_points = 2**6

RBA_gamma = 0.999
RBA_eta = 0.01

seed = 42

num_epochs = 5000

opt_type = optax.adam(learning_rate=0.001)

pow_basis = 1.75
pow_res = 0.25

# --------------------------
# Small architecture details
# --------------------------
G_small = 5
hidden_small = [8, 8]

params_small_lecun = {'k': 3, 'G': G_small, 'grid_range': (-1.0, 1.0), 'grid_e': 1.0, 'residual': nnx.silu, 'external_weights': True, 'add_bias': True,
                         'init_scheme': {'type': 'lecun', 'gain': None, 'distribution': 'uniform'}}
# ------------------------
# Big architecture details
# ------------------------
G_big = 20
hidden_big = [32, 32, 32]

params_big_lecun = {'k': 3, 'G': G_big, 'grid_range': (-1.0, 1.0), 'grid_e': 1.0, 'residual': nnx.silu, 'external_weights': True, 'add_bias': True,
                         'init_scheme': {'type': 'lecun', 'gain': None, 'distribution': 'uniform'}}

# %%
# Experiment
# Initialize results dict
results = dict()

for pde_name in pde_dict.keys():
    print(f"Running Experiments for {pde_name} equation.")
    pde_res = pde_dict[pde_name]
    results[pde_name] = dict()

    results[pde_name]['small'] = dict()
    results[pde_name]['big'] = dict()

    # Define the loss function for this PDE
    def loss_fn(model, l_E, l_B, pde_collocs, bc_collocs, bc_data):

        # ------------- PDE ---------------------------- #
        pde_residuals = pde_res(model, pde_collocs)
    
        # Get new RBA weights
        abs_pde_res = jnp.abs(pde_residuals)
        l_E_new = (RBA_gamma*l_E) + (RBA_eta*abs_pde_res/jnp.max(abs_pde_res))
    
        # Multiply by RBA weights
        w_resids_pde = l_E_new * pde_residuals
    
        # Get loss
        pde_loss = jnp.mean(w_resids_pde**2)
    
    
        # ------------- BC ----------------------------- #
        bc_residuals = model(bc_collocs) - bc_data
    
        # Get new RBA weights
        abs_bc_res = jnp.abs(bc_residuals)
        l_B_new = (RBA_gamma*l_B) + (RBA_eta*abs_bc_res/jnp.max(abs_bc_res))
    
        # Multiply by RBA weights
        w_resids_bc = l_B_new * bc_residuals
    
        # Loss
        bc_loss = jnp.mean(w_resids_bc**2)
    
        
        # ------------- Total --------------------------- #
        total_loss = pde_loss + bc_loss
    
        return total_loss, (l_E_new, l_B_new)
        
    # Define the train step
    @nnx.jit
    def train_step(model, optimizer, l_E, l_B, pde_collocs, bc_collocs, bc_data):
    
        (loss, (l_E_new, l_B_new)), grads = nnx.value_and_grad(loss_fn, has_aux = True)(model, l_E, l_B, pde_collocs, bc_collocs, bc_data)
    
        optimizer.update(grads)
    
        return loss, l_E_new, l_B_new

    # Get the reference solution
    refsol, coords = get_ref(pde_name)

    # Get collocation points
    pde_collocs, bc_collocs, bc_data = get_collocs(pde_name, N_points)

    # Model input/output
    n_in, n_out = pde_collocs.shape[1], bc_data.shape[1]

    # Small architecture
    layer_dims = [n_in, *hidden_small, n_out]

    print(f"\tTraining model with dimensions {layer_dims}.")

    # For confidence
    for run in [1, 2, 3, 4, 5]:

        results[pde_name]['small'][run] = dict()

        print(f"\t\tRun No. {run}.")

        # Baseline
        l_E = jnp.ones((pde_collocs.shape[0], 1))
        l_B = jnp.ones((bc_collocs.shape[0], 1))
        
        base_model = KAN(layer_dims = layer_dims, layer_type = 'spline', required_parameters = params_small_lecun, seed = seed+run)
        base_opt = nnx.Optimizer(base_model, opt_type)

        train_losses = jnp.zeros((num_epochs,))
        for epoch in range(num_epochs):
            loss, l_E, l_B = train_step(base_model, base_opt, l_E, l_B, pde_collocs, bc_collocs, bc_data)
            train_losses = train_losses.at[epoch].set(loss)

        results[pde_name]['small'][run]['lecun'] = train_losses.copy()

        print(f"\t\t\tLeCun model: Final Loss = {loss:.2e}")

    # Big architecture
    layer_dims = [n_in, *hidden_big, n_out]

    print(f"\tTraining model with dimensions {layer_dims}.")

    # For confidence
    for run in [1, 2, 3, 4, 5]:

        results[pde_name]['big'][run] = dict()

        print(f"\t\tRun No. {run}.")

        # Baseline
        l_E = jnp.ones((pde_collocs.shape[0], 1))
        l_B = jnp.ones((bc_collocs.shape[0], 1))
        
        base_model = KAN(layer_dims = layer_dims, layer_type = 'spline', required_parameters = params_big_lecun, seed = seed+run)
        base_opt = nnx.Optimizer(base_model, opt_type)

        train_losses = jnp.zeros((num_epochs,))
        for epoch in range(num_epochs):
            loss, l_E, l_B = train_step(base_model, base_opt, l_E, l_B, pde_collocs, bc_collocs, bc_data)
            train_losses = train_losses.at[epoch].set(loss)

        results[pde_name]['big'][run]['lecun'] = train_losses.copy()

        print(f"\t\t\tLeCun model: Final Loss = {loss:.2e}")
# Out:
# Running Experiments for allen-cahn equation.
# 	Training model with dimensions [2, 8, 8, 1].
# 		Run No. 1.
# 2025-11-14 10:28:21.075649: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2025-11-14 10:28:21.075697: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 			LeCun model: Final Loss = 1.86e-02
# 		Run No. 2.
# 			LeCun model: Final Loss = 1.70e-02
# 		Run No. 3.
# 			LeCun model: Final Loss = 2.54e-02
# 		Run No. 4.
# 			LeCun model: Final Loss = 1.51e-02
# 		Run No. 5.
# 			LeCun model: Final Loss = 1.82e-02
# 	Training model with dimensions [2, 32, 32, 32, 1].
# 		Run No. 1.
# 2025-11-14 10:29:22.003232: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2025-11-14 10:29:22.003280: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2025-11-14 10:29:22.003292: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2025-11-14 10:29:22.003299: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2025-11-14 10:29:22.003355: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2025-11-14 10:29:22.003359: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2025-11-14 10:29:22.003399: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 			LeCun model: Final Loss = 1.34e+02
# 		Run No. 2.
# 			LeCun model: Final Loss = 1.02e+02
# 		Run No. 3.
# 			LeCun model: Final Loss = 1.23e+02
# 		Run No. 4.
# 			LeCun model: Final Loss = 1.20e+02
# 		Run No. 5.
# 			LeCun model: Final Loss = 1.16e+02
# Running Experiments for burgers equation.
# 	Training model with dimensions [2, 8, 8, 1].
# 		Run No. 1.
# 2025-11-14 10:33:04.638632: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 			LeCun model: Final Loss = 4.48e-02
# 		Run No. 2.
# 			LeCun model: Final Loss = 4.04e-02
# 		Run No. 3.
# 			LeCun model: Final Loss = 3.76e-02
# 		Run No. 4.
# 			LeCun model: Final Loss = 1.13e-01
# 		Run No. 5.
# 			LeCun model: Final Loss = 3.27e-02
# 	Training model with dimensions [2, 32, 32, 32, 1].
# 		Run No. 1.
# 			LeCun model: Final Loss = 6.13e+04
# 		Run No. 2.
# 			LeCun model: Final Loss = 3.41e+04
# 		Run No. 3.
# 			LeCun model: Final Loss = 4.76e+04
# 		Run No. 4.
# 			LeCun model: Final Loss = 5.23e+04
# 		Run No. 5.
# 			LeCun model: Final Loss = 6.97e+04
# Running Experiments for helmholtz equation.
# 	Training model with dimensions [2, 8, 8, 1].
# 		Run No. 1.
# 2025-11-14 10:40:02.249769: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 			LeCun model: Final Loss = 3.06e+01
# 		Run No. 2.
# 			LeCun model: Final Loss = 2.47e+01
# 		Run No. 3.
# 			LeCun model: Final Loss = 2.66e+01
# 		Run No. 4.
# 			LeCun model: Final Loss = 2.37e+01
# 		Run No. 5.
# 			LeCun model: Final Loss = 3.27e+01
# 	Training model with dimensions [2, 32, 32, 32, 1].
# 		Run No. 1.
# 2025-11-14 10:41:10.825891: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2025-11-14 10:41:10.825950: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2025-11-14 10:41:10.825963: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2025-11-14 10:41:10.825970: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 2025-11-14 10:41:10.825978: W external/xla/xla/service/gpu/autotuning/dot_search_space.cc:200] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs?Working around this by using the full hints set instead.
# 			LeCun model: Final Loss = 1.00e+10
# 		Run No. 2.
# 			LeCun model: Final Loss = 8.22e+09
# 		Run No. 3.
# 			LeCun model: Final Loss = 1.06e+10
# 		Run No. 4.
# 			LeCun model: Final Loss = 1.05e+10
# 		Run No. 5.
# 			LeCun model: Final Loss = 1.23e+10

# %%
# Save results for further processing
results_dir = 'pde_results/'

with open(os.path.join(results_dir, "losses_lecun.pkl"), "wb") as f:
    pickle.dump(results, f)
